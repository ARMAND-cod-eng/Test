# %% [markdown]
# # Topic 3 DQ 2

# %% [markdown]
# Suppose you are given a biased coin with unknown probability of landing heads. Design an experiment to estimate the probability of heads using probability theory. How would you determine the number of coin flips to achieve a certain level of confidence in your estimate? Additionally, how can Python be used to simulate this experiment and visualize the results? Provide a detailed description of your experiment and your reasoning behind your choices.

# %% [markdown]
# To estimate the probability of falling on heads for a biased coin whose probability of falling on heads is unknown, we can use a statistical approach called the binomial distribution.
# A binomial distribution can be thought of as the probability of success or failure in an experiment or investigation repeated several times.

# %%
#Here, we use the Numpy, random and Matplotlib libraries to simulate the biased coin toss experiment with Python.
import numpy as np
import random
import matplotlib.pyplot as plt

#
#we define the binomial function to landing heads.
#n -> number of tests in an experiment.
#prob_ty -> probability of success / heads.

def event(n,prob_ty):    
    Outcome = np.random.binomial(n,prob_ty)    
    return Outcome
Prob_ty = random.random()

 # Initialize an empty list
    
my_list = [] 
Prob_expt = []
for Trials in range(1, 100):
    

    Outcome = event(Trials,Prob_ty)
    x=Outcome/Trials

    # Add elements to the list
    
    my_list.append(Outcome)  
    
    Prob_expt.append(x)
    

for i in Prob_expt:
    
    print("Number of Heads in each Experiment:\n",i)
# Out:
# Number of Heads in each Experiment:
#  0.0
# Number of Heads in each Experiment:
#  1.0
# Number of Heads in each Experiment:
#  1.0
# Number of Heads in each Experiment:
#  1.0
# Number of Heads in each Experiment:
#  1.0
# Number of Heads in each Experiment:
#  1.0
# Number of Heads in each Experiment:
#  0.8571428571428571
# Number of Heads in each Experiment:
#  1.0
# Number of Heads in each Experiment:
#  0.8888888888888888
# Number of Heads in each Experiment:
#  0.9
# Number of Heads in each Experiment:
#  0.9090909090909091
# Number of Heads in each Experiment:
#  0.75
# Number of Heads in each Experiment:
#  0.9230769230769231
# Number of Heads in each Experiment:
#  0.9285714285714286
# Number of Heads in each Experiment:
#  1.0
# Number of Heads in each Experiment:
#  0.875
# Number of Heads in each Experiment:
#  0.9411764705882353
# Number of Heads in each Experiment:
#  0.9444444444444444
# Number of Heads in each Experiment:
#  1.0
# Number of Heads in each Experiment:
#  0.9
# Number of Heads in each Experiment:
#  0.9523809523809523
# Number of Heads in each Experiment:
#  1.0
# Number of Heads in each Experiment:
#  0.9565217391304348
# Number of Heads in each Experiment:
#  0.9583333333333334
# Number of Heads in each Experiment:
#  0.96
# Number of Heads in each Experiment:
#  1.0
# Number of Heads in each Experiment:
#  1.0
# Number of Heads in each Experiment:
#  0.9642857142857143
# Number of Heads in each Experiment:
#  0.896551724137931
# Number of Heads in each Experiment:
#  0.9666666666666667
# Number of Heads in each Experiment:
#  0.967741935483871
# Number of Heads in each Experiment:
#  0.9375
# Number of Heads in each Experiment:
#  0.8787878787878788
# Number of Heads in each Experiment:
#  0.9117647058823529
# Number of Heads in each Experiment:
#  0.8857142857142857
# Number of Heads in each Experiment:
#  0.8611111111111112
# Number of Heads in each Experiment:
#  0.972972972972973
# Number of Heads in each Experiment:
#  0.8947368421052632
# Number of Heads in each Experiment:
#  0.8461538461538461
# Number of Heads in each Experiment:
#  0.95
# Number of Heads in each Experiment:
#  0.926829268292683
# Number of Heads in each Experiment:
#  1.0
# Number of Heads in each Experiment:
#  1.0
# Number of Heads in each Experiment:
#  0.9090909090909091
# Number of Heads in each Experiment:
#  0.9333333333333333
# Number of Heads in each Experiment:
#  0.9782608695652174
# Number of Heads in each Experiment:
#  0.9574468085106383
# Number of Heads in each Experiment:
#  0.8958333333333334
# Number of Heads in each Experiment:
#  0.8979591836734694
# Number of Heads in each Experiment:
#  1.0
# Number of Heads in each Experiment:
#  0.9607843137254902
# Number of Heads in each Experiment:
#  0.9230769230769231
# Number of Heads in each Experiment:
#  0.9622641509433962
# Number of Heads in each Experiment:
#  0.8888888888888888
# Number of Heads in each Experiment:
#  0.9272727272727272
# Number of Heads in each Experiment:
#  0.9464285714285714
# Number of Heads in each Experiment:
#  0.8596491228070176
# Number of Heads in each Experiment:
#  0.896551724137931
# Number of Heads in each Experiment:
#  0.9491525423728814
# Number of Heads in each Experiment:
#  0.9166666666666666
# Number of Heads in each Experiment:
#  0.9836065573770492
# Number of Heads in each Experiment:
#  0.9193548387096774
# Number of Heads in each Experiment:
#  0.9682539682539683
# Number of Heads in each Experiment:
#  0.9375
# Number of Heads in each Experiment:
#  0.9230769230769231
# Number of Heads in each Experiment:
#  0.9545454545454546
# Number of Heads in each Experiment:
#  0.9253731343283582
# Number of Heads in each Experiment:
#  0.9264705882352942
# Number of Heads in each Experiment:
#  0.9710144927536232
# Number of Heads in each Experiment:
#  0.9142857142857143
# Number of Heads in each Experiment:
#  0.9295774647887324
# Number of Heads in each Experiment:
#  0.8888888888888888
# Number of Heads in each Experiment:
#  0.9452054794520548
# Number of Heads in each Experiment:
#  0.9324324324324325
# Number of Heads in each Experiment:
#  0.92
# Number of Heads in each Experiment:
#  0.9868421052631579
# Number of Heads in each Experiment:
#  0.935064935064935
# Number of Heads in each Experiment:
#  0.9230769230769231
# Number of Heads in each Experiment:
#  0.9493670886075949
# Number of Heads in each Experiment:
#  0.9375
# Number of Heads in each Experiment:
#  0.9629629629629629
# Number of Heads in each Experiment:
#  0.975609756097561
# Number of Heads in each Experiment:
#  0.9518072289156626
# Number of Heads in each Experiment:
#  0.9761904761904762
# Number of Heads in each Experiment:
#  0.9294117647058824
# Number of Heads in each Experiment:
#  0.8837209302325582
# Number of Heads in each Experiment:
#  0.9655172413793104
# Number of Heads in each Experiment:
#  0.9318181818181818
# Number of Heads in each Experiment:
#  0.9101123595505618
# Number of Heads in each Experiment:
#  0.9444444444444444
# Number of Heads in each Experiment:
#  0.9230769230769231
# Number of Heads in each Experiment:
#  0.9239130434782609
# Number of Heads in each Experiment:
#  0.946236559139785
# Number of Heads in each Experiment:
#  0.9148936170212766
# Number of Heads in each Experiment:
#  0.968421052631579
# Number of Heads in each Experiment:
#  0.9375
# Number of Heads in each Experiment:
#  0.9587628865979382
# Number of Heads in each Experiment:
#  0.9081632653061225
# Number of Heads in each Experiment:
#  0.9393939393939394

# %%
plt.plot(Prob_expt)
plt.xlabel('Number of Heads in each Experiment')
plt.ylabel('Probability of Occurrence',)
plt.show()

# %% [markdown]
# we see that the probabilities are very different, so it is impossible to determine the probability of heads.

# %% [markdown]
# # we go from 100 tests to 10000 tests

# %%
my_list = []  # Initialize an empty list
Prob_expt = []
for Trials in range(1, 10000,100):
    

    Outcome = event(Trials,Prob_ty)
    x=Outcome/Trials

    my_list.append(Outcome)  # Add elements to the list
    
    Prob_expt.append(x)
    

for i in Prob_expt:
    
    print("Number of Heads in each Experiment:\n",i)
# Out:
# Number of Heads in each Experiment:
#  1.0
# Number of Heads in each Experiment:
#  0.9603960396039604
# Number of Heads in each Experiment:
#  0.9253731343283582
# Number of Heads in each Experiment:
#  0.9700996677740864
# Number of Heads in each Experiment:
#  0.9226932668329177
# Number of Heads in each Experiment:
#  0.9441117764471058
# Number of Heads in each Experiment:
#  0.956738768718802
# Number of Heads in each Experiment:
#  0.9400855920114123
# Number of Heads in each Experiment:
#  0.9525593008739076
# Number of Heads in each Experiment:
#  0.9456159822419534
# Number of Heads in each Experiment:
#  0.9310689310689311
# Number of Heads in each Experiment:
#  0.9455040871934605
# Number of Heads in each Experiment:
#  0.9408825978351374
# Number of Heads in each Experiment:
#  0.9362029208301307
# Number of Heads in each Experiment:
#  0.9421841541755889
# Number of Heads in each Experiment:
#  0.9347101932045303
# Number of Heads in each Experiment:
#  0.9325421611492817
# Number of Heads in each Experiment:
#  0.9506172839506173
# Number of Heads in each Experiment:
#  0.9522487506940589
# Number of Heads in each Experiment:
#  0.9510783798001052
# Number of Heads in each Experiment:
#  0.9435282358820589
# Number of Heads in each Experiment:
#  0.9466920514040933
# Number of Heads in each Experiment:
#  0.9459336665152204
# Number of Heads in each Experiment:
#  0.9461103867883529
# Number of Heads in each Experiment:
#  0.9400249895876718
# Number of Heads in each Experiment:
#  0.9388244702119153
# Number of Heads in each Experiment:
#  0.942714340638216
# Number of Heads in each Experiment:
#  0.93891151425398
# Number of Heads in each Experiment:
#  0.9346661906461978
# Number of Heads in each Experiment:
#  0.9441571871768356
# Number of Heads in each Experiment:
#  0.9380206597800733
# Number of Heads in each Experiment:
#  0.9506610770719123
# Number of Heads in each Experiment:
#  0.9456419868791003
# Number of Heads in each Experiment:
#  0.9375946682823387
# Number of Heads in each Experiment:
#  0.9450161717142017
# Number of Heads in each Experiment:
#  0.9394458726078263
# Number of Heads in each Experiment:
#  0.946126076089975
# Number of Heads in each Experiment:
#  0.9448797622264253
# Number of Heads in each Experiment:
#  0.939752696658774
# Number of Heads in each Experiment:
#  0.9407844142527557
# Number of Heads in each Experiment:
#  0.9430142464383904
# Number of Heads in each Experiment:
#  0.9463545476712997
# Number of Heads in each Experiment:
#  0.9409664365627232
# Number of Heads in each Experiment:
#  0.9400139502441293
# Number of Heads in each Experiment:
#  0.946603044762554
# Number of Heads in each Experiment:
#  0.9471228615863142
# Number of Heads in each Experiment:
#  0.9437078895892197
# Number of Heads in each Experiment:
#  0.9440544564986173
# Number of Heads in each Experiment:
#  0.9475109352218288
# Number of Heads in each Experiment:
#  0.9440930422362783
# Number of Heads in each Experiment:
#  0.9436112777444511
# Number of Heads in each Experiment:
#  0.9382474024701039
# Number of Heads in each Experiment:
#  0.9402038069602
# Number of Heads in each Experiment:
#  0.9341633654027542
# Number of Heads in each Experiment:
#  0.9416774671357157
# Number of Heads in each Experiment:
#  0.9381930558080349
# Number of Heads in each Experiment:
#  0.946616675593644
# Number of Heads in each Experiment:
#  0.9465006139273812
# Number of Heads in each Experiment:
#  0.9456990174107912
# Number of Heads in each Experiment:
#  0.9428910354177258
# Number of Heads in each Experiment:
#  0.9450091651391435
# Number of Heads in each Experiment:
#  0.941321094902475
# Number of Heads in each Experiment:
#  0.9388808256732785
# Number of Heads in each Experiment:
#  0.9395334073956515
# Number of Heads in each Experiment:
#  0.9415716294329011
# Number of Heads in each Experiment:
#  0.9441624365482234
# Number of Heads in each Experiment:
#  0.9377367065596122
# Number of Heads in each Experiment:
#  0.9404566482614535
# Number of Heads in each Experiment:
#  0.9416262314365534
# Number of Heads in each Experiment:
#  0.9392841617156934
# Number of Heads in each Experiment:
#  0.9417226110555635
# Number of Heads in each Experiment:
#  0.9432474299394451
# Number of Heads in each Experiment:
#  0.9438966810165255
# Number of Heads in each Experiment:
#  0.9416518285166415
# Number of Heads in each Experiment:
#  0.9431157951628159
# Number of Heads in each Experiment:
#  0.9413411545127316
# Number of Heads in each Experiment:
#  0.9398763320615708
# Number of Heads in each Experiment:
#  0.9422152967147124
# Number of Heads in each Experiment:
#  0.9405204460966543
# Number of Heads in each Experiment:
#  0.9441842804708265
# Number of Heads in each Experiment:
#  0.941132358455193
# Number of Heads in each Experiment:
#  0.9454388347117639
# Number of Heads in each Experiment:
#  0.9385440799902451
# Number of Heads in each Experiment:
#  0.9418142392482833
# Number of Heads in each Experiment:
#  0.9436971789072729
# Number of Heads in each Experiment:
#  0.9420068227267381
# Number of Heads in each Experiment:
#  0.9388443204278573
# Number of Heads in each Experiment:
#  0.942305482128491
# Number of Heads in each Experiment:
#  0.9404613112146347
# Number of Heads in each Experiment:
#  0.9400067408156387
# Number of Heads in each Experiment:
#  0.940451060993223
# Number of Heads in each Experiment:
#  0.9402263487528842
# Number of Heads in each Experiment:
#  0.946092815998261
# Number of Heads in each Experiment:
#  0.9453822169659176
# Number of Heads in each Experiment:
#  0.9380916923731518
# Number of Heads in each Experiment:
#  0.9397958109672666
# Number of Heads in each Experiment:
#  0.9435475471305073
# Number of Heads in each Experiment:
#  0.9432017317802288
# Number of Heads in each Experiment:
#  0.945821854912764
# Number of Heads in each Experiment:
#  0.9442480557519443

# %%
plt.plot(Prob_expt)
plt.xlabel('Number of Heads in each Experiment')
plt.ylabel('Probability of Occurrence',)
plt.show()

# %% [markdown]
# we see that the probabilities are close to 0.94, but are slightly different, so it's impossible to determine the probability of heads.

# %% [markdown]
# # we go from 10000 test to 1000000 test

# %%
my_list = []  # Initialize an empty list
Prob_expt = []
for Trials in range(10, 10**6, 1000):
    

    Outcome = event(Trials,Prob_ty)
    x=Outcome/Trials

    my_list.append(Outcome)  # Add elements to the list
    
    Prob_expt.append(x)
    

for i in Prob_expt:
    
    print("Number of Heads in each Experiment:\n",i)
# Out:
# Number of Heads in each Experiment:
#  1.0
# Number of Heads in each Experiment:
#  0.9524752475247524
# Number of Heads in each Experiment:
#  0.9303482587064676
# Number of Heads in each Experiment:
#  0.9385382059800664
# Number of Heads in each Experiment:
#  0.9423940149625936
# Number of Heads in each Experiment:
#  0.9405189620758483
# Number of Heads in each Experiment:
#  0.9394342762063228
# Number of Heads in each Experiment:
#  0.9393723252496433
# Number of Heads in each Experiment:
#  0.9440699126092384
# Number of Heads in each Experiment:
#  0.9387347391786903
# Number of Heads in each Experiment:
#  0.9421578421578422
# Number of Heads in each Experiment:
#  0.9410535876475931
# Number of Heads in each Experiment:
#  0.9467110741049126
# Number of Heads in each Experiment:
#  0.939815526518063
# Number of Heads in each Experiment:
#  0.9454675231977159
# Number of Heads in each Experiment:
#  0.9432378414390407
# Number of Heads in each Experiment:
#  0.9391005621486571
# Number of Heads in each Experiment:
#  0.944620811287478
# Number of Heads in each Experiment:
#  0.9423098278734037
# Number of Heads in each Experiment:
#  0.9430825881115202
# Number of Heads in each Experiment:
#  0.9423788105947026
# Number of Heads in each Experiment:
#  0.9419800095192765
# Number of Heads in each Experiment:
#  0.9428895956383462
# Number of Heads in each Experiment:
#  0.9432855280312907
# Number of Heads in each Experiment:
#  0.9449812578092461
# Number of Heads in each Experiment:
#  0.9435025989604159
# Number of Heads in each Experiment:
#  0.9406766628219916
# Number of Heads in each Experiment:
#  0.9410958904109589
# Number of Heads in each Experiment:
#  0.944162799000357
# Number of Heads in each Experiment:
#  0.9418131678731472
# Number of Heads in each Experiment:
#  0.9451182939020326
# Number of Heads in each Experiment:
#  0.9436633344082554
# Number of Heads in each Experiment:
#  0.9416744767260231
# Number of Heads in each Experiment:
#  0.9407149348682218
# Number of Heads in each Experiment:
#  0.9439576595119082
# Number of Heads in each Experiment:
#  0.9425592687803485
# Number of Heads in each Experiment:
#  0.9419327964454318
# Number of Heads in each Experiment:
#  0.9434747365576871
# Number of Heads in each Experiment:
#  0.9397000789265982
# Number of Heads in each Experiment:
#  0.9409894898743911
# Number of Heads in each Experiment:
#  0.9418645338665333
# Number of Heads in each Experiment:
#  0.9431602048280907
# Number of Heads in each Experiment:
#  0.9436086646036658
# Number of Heads in each Experiment:
#  0.9425714950011626
# Number of Heads in each Experiment:
#  0.9413996818904794
# Number of Heads in each Experiment:
#  0.9410575427682737
# Number of Heads in each Experiment:
#  0.9412953705716148
# Number of Heads in each Experiment:
#  0.9428206764518188
# Number of Heads in each Experiment:
#  0.9421578837742137
# Number of Heads in each Experiment:
#  0.9423382983064681
# Number of Heads in each Experiment:
#  0.9420315936812638
# Number of Heads in each Experiment:
#  0.9416192903352284
# Number of Heads in each Experiment:
#  0.9415304749086714
# Number of Heads in each Experiment:
#  0.9405206564799095
# Number of Heads in each Experiment:
#  0.9395852619885207
# Number of Heads in each Experiment:
#  0.9435738956553354
# Number of Heads in each Experiment:
#  0.941831815747188
# Number of Heads in each Experiment:
#  0.9412383792317137
# Number of Heads in each Experiment:
#  0.9428374418203758
# Number of Heads in each Experiment:
#  0.9436536180308422
# Number of Heads in each Experiment:
#  0.9427928678553574
# Number of Heads in each Experiment:
#  0.9425995738403541
# Number of Heads in each Experiment:
#  0.9425899048540558
# Number of Heads in each Experiment:
#  0.941691794953182
# Number of Heads in each Experiment:
#  0.943118262771442
# Number of Heads in each Experiment:
#  0.9414397784956161
# Number of Heads in each Experiment:
#  0.942448113922133
# Number of Heads in each Experiment:
#  0.9421578868825549
# Number of Heads in each Experiment:
#  0.9418908983972946
# Number of Heads in each Experiment:
#  0.9415157223590784
# Number of Heads in each Experiment:
#  0.9414512212541065
# Number of Heads in each Experiment:
#  0.9422334882410928
# Number of Heads in each Experiment:
#  0.9419941674767394
# Number of Heads in each Experiment:
#  0.9423092727023695
# Number of Heads in each Experiment:
#  0.9420753952168626
# Number of Heads in each Experiment:
#  0.9429142780962538
# Number of Heads in each Experiment:
#  0.9420339429022497
# Number of Heads in each Experiment:
#  0.9427476951045318
# Number of Heads in each Experiment:
#  0.9437764389180874
# Number of Heads in each Experiment:
#  0.9423364131122642
# Number of Heads in each Experiment:
#  0.9421322334708161
# Number of Heads in each Experiment:
#  0.9444389581533144
# Number of Heads in each Experiment:
#  0.9417388123399585
# Number of Heads in each Experiment:
#  0.9421997349716902
# Number of Heads in each Experiment:
#  0.9415664801809308
# Number of Heads in each Experiment:
#  0.9419244794730032
# Number of Heads in each Experiment:
#  0.9423439134984304
# Number of Heads in each Experiment:
#  0.9414779910355131
# Number of Heads in each Experiment:
#  0.9416429951141916
# Number of Heads in each Experiment:
#  0.941568363105269
# Number of Heads in each Experiment:
#  0.9417731363181868
# Number of Heads in each Experiment:
#  0.9417316778376003
# Number of Heads in each Experiment:
#  0.9432887729594609
# Number of Heads in each Experiment:
#  0.9427588431351468
# Number of Heads in each Experiment:
#  0.9421976385490906
# Number of Heads in each Experiment:
#  0.9440374697400273
# Number of Heads in each Experiment:
#  0.9404853661076971
# Number of Heads in each Experiment:
#  0.9418719719616534
# Number of Heads in each Experiment:
#  0.9429548005305581
# Number of Heads in each Experiment:
#  0.9434299565700435
# Number of Heads in each Experiment:
#  0.9411558844115588
# Number of Heads in each Experiment:
#  0.9412335412335412
# Number of Heads in each Experiment:
#  0.9434565238702088
# Number of Heads in each Experiment:
#  0.9417920590233958
# Number of Heads in each Experiment:
#  0.941409479857706
# Number of Heads in each Experiment:
#  0.9434434815731835
# Number of Heads in each Experiment:
#  0.9412602584661824
# Number of Heads in each Experiment:
#  0.9430800859732735
# Number of Heads in each Experiment:
#  0.9413295065271734
# Number of Heads in each Experiment:
#  0.9413264838088249
# Number of Heads in each Experiment:
#  0.9432324334151441
# Number of Heads in each Experiment:
#  0.9424376182325916
# Number of Heads in each Experiment:
#  0.9423801446299438
# Number of Heads in each Experiment:
#  0.9421467126802938
# Number of Heads in each Experiment:
#  0.9420489430751688
# Number of Heads in each Experiment:
#  0.9423528388835753
# Number of Heads in each Experiment:
#  0.942168778553573
# Number of Heads in each Experiment:
#  0.9421758824032134
# Number of Heads in each Experiment:
#  0.9418354376747733
# Number of Heads in each Experiment:
#  0.9419964708847995
# Number of Heads in each Experiment:
#  0.9404549620864928
# Number of Heads in each Experiment:
#  0.9417734071564333
# Number of Heads in each Experiment:
#  0.9417096959265634
# Number of Heads in each Experiment:
#  0.9415169498414763
# Number of Heads in each Experiment:
#  0.941206354326264
# Number of Heads in each Experiment:
#  0.9409007279417647
# Number of Heads in each Experiment:
#  0.9425997936671693
# Number of Heads in each Experiment:
#  0.943594992520274
# Number of Heads in each Experiment:
#  0.9409030544488712
# Number of Heads in each Experiment:
#  0.9428803968684598
# Number of Heads in each Experiment:
#  0.9420429197754019
# Number of Heads in each Experiment:
#  0.9434852301351042
# Number of Heads in each Experiment:
#  0.9412696007878191
# Number of Heads in each Experiment:
#  0.9431696864897376
# Number of Heads in each Experiment:
#  0.9424296694276546
# Number of Heads in each Experiment:
#  0.9428486778757129
# Number of Heads in each Experiment:
#  0.9423498272185868
# Number of Heads in each Experiment:
#  0.9413400481716663
# Number of Heads in each Experiment:
#  0.9411926671980291
# Number of Heads in each Experiment:
#  0.9425005395295303
# Number of Heads in each Experiment:
#  0.9415398900078565
# Number of Heads in each Experiment:
#  0.9429827671796327
# Number of Heads in each Experiment:
#  0.9424477149496514
# Number of Heads in each Experiment:
#  0.9426403747989651
# Number of Heads in each Experiment:
#  0.9428234150406222
# Number of Heads in each Experiment:
#  0.9413074960347563
# Number of Heads in each Experiment:
#  0.9424833915485241
# Number of Heads in each Experiment:
#  0.9422352220937351
# Number of Heads in each Experiment:
#  0.9422336328626444
# Number of Heads in each Experiment:
#  0.9426213005838534
# Number of Heads in each Experiment:
#  0.9425171655222985
# Number of Heads in each Experiment:
#  0.9420833057413416
# Number of Heads in each Experiment:
#  0.941885402276166
# Number of Heads in each Experiment:
#  0.9418077249852951
# Number of Heads in each Experiment:
#  0.9421596000259723
# Number of Heads in each Experiment:
#  0.9427585317076318
# Number of Heads in each Experiment:
#  0.9417024549708352
# Number of Heads in each Experiment:
#  0.9434621998598816
# Number of Heads in each Experiment:
#  0.9416112904246566
# Number of Heads in each Experiment:
#  0.9417395132381611
# Number of Heads in each Experiment:
#  0.943053559152553
# Number of Heads in each Experiment:
#  0.9427426867896403
# Number of Heads in each Experiment:
#  0.9419603728164928
# Number of Heads in each Experiment:
#  0.9424145757928961
# Number of Heads in each Experiment:
#  0.9420584110724955
# Number of Heads in each Experiment:
#  0.9409732743470093
# Number of Heads in each Experiment:
#  0.9421902295042467
# Number of Heads in each Experiment:
#  0.9409197054068619
# Number of Heads in each Experiment:
#  0.9422653413487292
# Number of Heads in each Experiment:
#  0.9420034317496007
# Number of Heads in each Experiment:
#  0.9420504676195518
# Number of Heads in each Experiment:
#  0.9426349336296123
# Number of Heads in each Experiment:
#  0.9408290215685134
# Number of Heads in each Experiment:
#  0.9424888734755217
# Number of Heads in each Experiment:
#  0.94133095799092
# Number of Heads in each Experiment:
#  0.9422661562196446
# Number of Heads in each Experiment:
#  0.9417192204988353
# Number of Heads in each Experiment:
#  0.9432348454889554
# Number of Heads in each Experiment:
#  0.9425313184652547
# Number of Heads in each Experiment:
#  0.9413440589911178
# Number of Heads in each Experiment:
#  0.941025498583412
# Number of Heads in each Experiment:
#  0.9417711728633777
# Number of Heads in each Experiment:
#  0.9410362068018241
# Number of Heads in each Experiment:
#  0.9429976504016174
# Number of Heads in each Experiment:
#  0.9415575240476061
# Number of Heads in each Experiment:
#  0.9415869412464191
# Number of Heads in each Experiment:
#  0.9421321434331488
# Number of Heads in each Experiment:
#  0.9423774129725683
# Number of Heads in each Experiment:
#  0.9424658262858359
# Number of Heads in each Experiment:
#  0.9422358605364796
# Number of Heads in each Experiment:
#  0.9421662017788538
# Number of Heads in each Experiment:
#  0.9422805088738809
# Number of Heads in each Experiment:
#  0.9421280141659288
# Number of Heads in each Experiment:
#  0.9430392207657634
# Number of Heads in each Experiment:
#  0.9425441987526416
# Number of Heads in each Experiment:
#  0.9416799138505718
# Number of Heads in each Experiment:
#  0.9422274373756441
# Number of Heads in each Experiment:
#  0.9424090147708238
# Number of Heads in each Experiment:
#  0.9416494116458765
# Number of Heads in each Experiment:
#  0.9419074418370936
# Number of Heads in each Experiment:
#  0.9429578521073946
# Number of Heads in each Experiment:
#  0.941774041092483
# Number of Heads in each Experiment:
#  0.9422998861442503
# Number of Heads in each Experiment:
#  0.9420225604650018
# Number of Heads in each Experiment:
#  0.9431645507573159
# Number of Heads in each Experiment:
#  0.9425247548900053
# Number of Heads in each Experiment:
#  0.9420173777971943
# Number of Heads in each Experiment:
#  0.9423264576590503
# Number of Heads in each Experiment:
#  0.9420172107110235
# Number of Heads in each Experiment:
#  0.9419405770058848
# Number of Heads in each Experiment:
#  0.9425455930669968
# Number of Heads in each Experiment:
#  0.9426899199090091
# Number of Heads in each Experiment:
#  0.941917834064431
# Number of Heads in each Experiment:
#  0.9421106990282146
# Number of Heads in each Experiment:
#  0.9414373160132704
# Number of Heads in each Experiment:
#  0.9427189433049625
# Number of Heads in each Experiment:
#  0.9426693208647747
# Number of Heads in each Experiment:
#  0.9420072807704714
# Number of Heads in each Experiment:
#  0.9425852025136462
# Number of Heads in each Experiment:
#  0.9422492123647322
# Number of Heads in each Experiment:
#  0.9418799145493386
# Number of Heads in each Experiment:
#  0.9427220487760735
# Number of Heads in each Experiment:
#  0.9421377415431738
# Number of Heads in each Experiment:
#  0.9425541455540111
# Number of Heads in each Experiment:
#  0.942038301861524
# Number of Heads in each Experiment:
#  0.9418692502555442
# Number of Heads in each Experiment:
#  0.9428520861908765
# Number of Heads in each Experiment:
#  0.941575261001718
# Number of Heads in each Experiment:
#  0.9424191921406956
# Number of Heads in each Experiment:
#  0.9425134273612507
# Number of Heads in each Experiment:
#  0.9420938220077388
# Number of Heads in each Experiment:
#  0.9413142288212631
# Number of Heads in each Experiment:
#  0.9422783500711176
# Number of Heads in each Experiment:
#  0.9422213638899618
# Number of Heads in each Experiment:
#  0.9423571642237512
# Number of Heads in each Experiment:
#  0.9421982043317305
# Number of Heads in each Experiment:
#  0.9423837972967247
# Number of Heads in each Experiment:
#  0.9414370701658158
# Number of Heads in each Experiment:
#  0.9424477963110793
# Number of Heads in each Experiment:
#  0.9421948872432115
# Number of Heads in each Experiment:
#  0.9421232448647973
# Number of Heads in each Experiment:
#  0.9428198000082985
# Number of Heads in each Experiment:
#  0.9434238254617577
# Number of Heads in each Experiment:
#  0.9422287148677009
# Number of Heads in each Experiment:
#  0.9413138805786648
# Number of Heads in each Experiment:
#  0.9418023754132484
# Number of Heads in each Experiment:
#  0.9420064225031503
# Number of Heads in each Experiment:
#  0.9419578154730578
# Number of Heads in each Experiment:
#  0.9422079754848595
# Number of Heads in each Experiment:
#  0.9428215734307859
# Number of Heads in each Experiment:
#  0.9427102915883364
# Number of Heads in each Experiment:
#  0.9418668578941078
# Number of Heads in each Experiment:
#  0.9419745248204436
# Number of Heads in each Experiment:
#  0.9426228212323624
# Number of Heads in each Experiment:
#  0.9419353568757135
# Number of Heads in each Experiment:
#  0.9418140465079801
# Number of Heads in each Experiment:
#  0.9429631655013476
# Number of Heads in each Experiment:
#  0.942126765495506
# Number of Heads in each Experiment:
#  0.9428200457346615
# Number of Heads in each Experiment:
#  0.9433921470213505
# Number of Heads in each Experiment:
#  0.9419445405945925
# Number of Heads in each Experiment:
#  0.9418489713037814
# Number of Heads in each Experiment:
#  0.942242662493798
# Number of Heads in each Experiment:
#  0.942534504391468
# Number of Heads in each Experiment:
#  0.9424908147418658
# Number of Heads in each Experiment:
#  0.9423116108826082
# Number of Heads in each Experiment:
#  0.9415548287658358
# Number of Heads in each Experiment:
#  0.9427062656829333
# Number of Heads in each Experiment:
#  0.9426401999925376
# Number of Heads in each Experiment:
#  0.9425969294821754
# Number of Heads in each Experiment:
#  0.9413910595903855
# Number of Heads in each Experiment:
#  0.9427327404892808
# Number of Heads in each Experiment:
#  0.9424065291717216
# Number of Heads in each Experiment:
#  0.9426944067982858
# Number of Heads in each Experiment:
#  0.9423780154008978
# Number of Heads in each Experiment:
#  0.9427729900730882
# Number of Heads in each Experiment:
#  0.9422629614869027
# Number of Heads in each Experiment:
#  0.9426591097794303
# Number of Heads in each Experiment:
#  0.9424337254055609
# Number of Heads in each Experiment:
#  0.9415863230708577
# Number of Heads in each Experiment:
#  0.942341344951966
# Number of Heads in each Experiment:
#  0.9426034660688232
# Number of Heads in each Experiment:
#  0.941395695188114
# Number of Heads in each Experiment:
#  0.9419455142927812
# Number of Heads in each Experiment:
#  0.9414985387838456
# Number of Heads in each Experiment:
#  0.941865197712361
# Number of Heads in each Experiment:
#  0.9421418831509388
# Number of Heads in each Experiment:
#  0.9419671788439428
# Number of Heads in each Experiment:
#  0.9422485330370474
# Number of Heads in each Experiment:
#  0.9418428428082073
# Number of Heads in each Experiment:
#  0.9422295782904038
# Number of Heads in each Experiment:
#  0.9422012989244356
# Number of Heads in each Experiment:
#  0.942262251292764
# Number of Heads in each Experiment:
#  0.9428039998634858
# Number of Heads in each Experiment:
#  0.9413761436685827
# Number of Heads in each Experiment:
#  0.9423443273109386
# Number of Heads in each Experiment:
#  0.9423465423465424
# Number of Heads in each Experiment:
#  0.9418874785360762
# Number of Heads in each Experiment:
#  0.9424952182812657
# Number of Heads in each Experiment:
#  0.9417778669609712
# Number of Heads in each Experiment:
#  0.941645278490717
# Number of Heads in each Experiment:
#  0.9425002491611575
# Number of Heads in each Experiment:
#  0.9425151485050164
# Number of Heads in each Experiment:
#  0.94247714596878
# Number of Heads in each Experiment:
#  0.9422157165882701
# Number of Heads in each Experiment:
#  0.942015015901118
# Number of Heads in each Experiment:
#  0.942377700075161
# Number of Heads in each Experiment:
#  0.9424318426109899
# Number of Heads in each Experiment:
#  0.9424823869354891
# Number of Heads in each Experiment:
#  0.9416491375683634
# Number of Heads in each Experiment:
#  0.9423728266830103
# Number of Heads in each Experiment:
#  0.941921481624385
# Number of Heads in each Experiment:
#  0.9418031473350214
# Number of Heads in each Experiment:
#  0.9419219833232165
# Number of Heads in each Experiment:
#  0.9415146014458138
# Number of Heads in each Experiment:
#  0.9423129424462715
# Number of Heads in each Experiment:
#  0.9429290212335053
# Number of Heads in each Experiment:
#  0.9431279770354247
# Number of Heads in each Experiment:
#  0.9421150278293136
# Number of Heads in each Experiment:
#  0.9424406758408828
# Number of Heads in each Experiment:
#  0.942398675041405
# Number of Heads in each Experiment:
#  0.9420796859910906
# Number of Heads in each Experiment:
#  0.9426042669482314
# Number of Heads in each Experiment:
#  0.9420915761121946
# Number of Heads in each Experiment:
#  0.942301163544335
# Number of Heads in each Experiment:
#  0.9417679456016738
# Number of Heads in each Experiment:
#  0.9425078985307199
# Number of Heads in each Experiment:
#  0.9419773095623987
# Number of Heads in each Experiment:
#  0.9421633486783939
# Number of Heads in each Experiment:
#  0.9422844290447099
# Number of Heads in each Experiment:
#  0.9418563073846247
# Number of Heads in each Experiment:
#  0.9426633636446029
# Number of Heads in each Experiment:
#  0.9421583687238336
# Number of Heads in each Experiment:
#  0.9421098465511546
# Number of Heads in each Experiment:
#  0.941819107212359
# Number of Heads in each Experiment:
#  0.942088295871765
# Number of Heads in each Experiment:
#  0.9425195678700039
# Number of Heads in each Experiment:
#  0.9427465060383965
# Number of Heads in each Experiment:
#  0.9418123724150174
# Number of Heads in each Experiment:
#  0.9427509512993717
# Number of Heads in each Experiment:
#  0.9427134496044234
# Number of Heads in each Experiment:
#  0.9425999237559016
# Number of Heads in each Experiment:
#  0.9423350194438759
# Number of Heads in each Experiment:
#  0.9417888691291799
# Number of Heads in each Experiment:
#  0.9421848202087149
# Number of Heads in each Experiment:
#  0.9411437349642039
# Number of Heads in each Experiment:
#  0.9419756654431953
# Number of Heads in each Experiment:
#  0.9410939166018271
# Number of Heads in each Experiment:
#  0.9418292577799489
# Number of Heads in each Experiment:
#  0.9427752786453111
# Number of Heads in each Experiment:
#  0.9422473643610183
# Number of Heads in each Experiment:
#  0.9421697387538817
# Number of Heads in each Experiment:
#  0.9418539246044146
# Number of Heads in each Experiment:
#  0.9419846463272995
# Number of Heads in each Experiment:
#  0.9426146154063445
# Number of Heads in each Experiment:
#  0.9416607982873721
# Number of Heads in each Experiment:
#  0.9419061262324092
# Number of Heads in each Experiment:
#  0.9423209433909414
# Number of Heads in each Experiment:
#  0.9422837350911986
# Number of Heads in each Experiment:
#  0.9428706721261246
# Number of Heads in each Experiment:
#  0.9419655009583067
# Number of Heads in each Experiment:
#  0.9419462064762749
# Number of Heads in each Experiment:
#  0.9424767271622331
# Number of Heads in each Experiment:
#  0.942726095699843
# Number of Heads in each Experiment:
#  0.9421856542402681
# Number of Heads in each Experiment:
#  0.9420618613188679
# Number of Heads in each Experiment:
#  0.9421245321166088
# Number of Heads in each Experiment:
#  0.9417618048554536
# Number of Heads in each Experiment:
#  0.9423847178065814
# Number of Heads in each Experiment:
#  0.942153329178071
# Number of Heads in each Experiment:
#  0.9419042728574903
# Number of Heads in each Experiment:
#  0.9421605886633784
# Number of Heads in each Experiment:
#  0.9420983306900352
# Number of Heads in each Experiment:
#  0.9425136055333637
# Number of Heads in each Experiment:
#  0.941817063714874
# Number of Heads in each Experiment:
#  0.942406869150156
# Number of Heads in each Experiment:
#  0.9419988830084306
# Number of Heads in each Experiment:
#  0.9420864168059203
# Number of Heads in each Experiment:
#  0.94265760165075
# Number of Heads in each Experiment:
#  0.9425635207514313
# Number of Heads in each Experiment:
#  0.9418278466356148
# Number of Heads in each Experiment:
#  0.9422062413060025
# Number of Heads in each Experiment:
#  0.9422004659563886
# Number of Heads in each Experiment:
#  0.942241716926451
# Number of Heads in each Experiment:
#  0.9417124554048072
# Number of Heads in each Experiment:
#  0.9425547388379523
# Number of Heads in each Experiment:
#  0.9422683350172275
# Number of Heads in each Experiment:
#  0.9422418025374021
# Number of Heads in each Experiment:
#  0.9417411922373135
# Number of Heads in each Experiment:
#  0.9427803912495822
# Number of Heads in each Experiment:
#  0.9415091920719981
# Number of Heads in each Experiment:
#  0.94216004705762
# Number of Heads in each Experiment:
#  0.9415040432642025
# Number of Heads in each Experiment:
#  0.9417139512989491
# Number of Heads in each Experiment:
#  0.9420979162965407
# Number of Heads in each Experiment:
#  0.9414926204399888
# Number of Heads in each Experiment:
#  0.9421201484810989
# Number of Heads in each Experiment:
#  0.9418906324777714
# Number of Heads in each Experiment:
#  0.9421723072284616
# Number of Heads in each Experiment:
#  0.9423999398511316
# Number of Heads in each Experiment:
#  0.942103947401315
# Number of Heads in each Experiment:
#  0.9419391037629984
# Number of Heads in each Experiment:
#  0.941775080221885
# Number of Heads in each Experiment:
#  0.9420833229944666
# Number of Heads in each Experiment:
#  0.9421029182445979
# Number of Heads in each Experiment:
#  0.94214463840399
# Number of Heads in each Experiment:
#  0.941836407970247
# Number of Heads in each Experiment:
#  0.9426156605488809
# Number of Heads in each Experiment:
#  0.9418494644739099
# Number of Heads in each Experiment:
#  0.9421823427300066
# Number of Heads in each Experiment:
#  0.9424916465452062
# Number of Heads in each Experiment:
#  0.9424052942750785
# Number of Heads in each Experiment:
#  0.9419383024683867
# Number of Heads in each Experiment:
#  0.9423234304254134
# Number of Heads in each Experiment:
#  0.9424313422381102
# Number of Heads in each Experiment:
#  0.9429869159779283
# Number of Heads in each Experiment:
#  0.9423018677435638
# Number of Heads in each Experiment:
#  0.9418838876765545
# Number of Heads in each Experiment:
#  0.9415109686371139
# Number of Heads in each Experiment:
#  0.9422114030691392
# Number of Heads in each Experiment:
#  0.9422489940715697
# Number of Heads in each Experiment:
#  0.9419752499940619
# Number of Heads in each Experiment:
#  0.9425842989502619
# Number of Heads in each Experiment:
#  0.9425025413110801
# Number of Heads in each Experiment:
#  0.9426876724605552
# Number of Heads in each Experiment:
#  0.942598997670643
# Number of Heads in each Experiment:
#  0.942259571371564
# Number of Heads in each Experiment:
#  0.9417273600149879
# Number of Heads in each Experiment:
#  0.9424055512721665
# Number of Heads in each Experiment:
#  0.941835854642083
# Number of Heads in each Experiment:
#  0.9424827329596986
# Number of Heads in each Experiment:
#  0.9423076030718545
# Number of Heads in each Experiment:
#  0.9424596652855258
# Number of Heads in each Experiment:
#  0.9419990300454955
# Number of Heads in each Experiment:
#  0.9418193129190572
# Number of Heads in each Experiment:
#  0.9422794878278661
# Number of Heads in each Experiment:
#  0.9417398683516434
# Number of Heads in each Experiment:
#  0.9422187135305828
# Number of Heads in each Experiment:
#  0.9423095363119564
# Number of Heads in each Experiment:
#  0.9418259265164802
# Number of Heads in each Experiment:
#  0.9417899593191064
# Number of Heads in each Experiment:
#  0.9423686537720233
# Number of Heads in each Experiment:
#  0.9424130675776566
# Number of Heads in each Experiment:
#  0.9425814315703934
# Number of Heads in each Experiment:
#  0.9423976937456363
# Number of Heads in each Experiment:
#  0.9420889418215321
# Number of Heads in each Experiment:
#  0.9418062375283065
# Number of Heads in each Experiment:
#  0.9421310485224044
# Number of Heads in each Experiment:
#  0.9427445815941609
# Number of Heads in each Experiment:
#  0.9421371461660096
# Number of Heads in each Experiment:
#  0.9426612741939068
# Number of Heads in each Experiment:
#  0.9426198975632469
# Number of Heads in each Experiment:
#  0.9418530563483108
# Number of Heads in each Experiment:
#  0.9425288624975167
# Number of Heads in each Experiment:
#  0.9417942336071893
# Number of Heads in each Experiment:
#  0.9421001736225577
# Number of Heads in each Experiment:
#  0.942556084296397
# Number of Heads in each Experiment:
#  0.9412726198551454
# Number of Heads in each Experiment:
#  0.9423833540752385
# Number of Heads in each Experiment:
#  0.9422365525805538
# Number of Heads in each Experiment:
#  0.9425186408991109
# Number of Heads in each Experiment:
#  0.9416259950977203
# Number of Heads in each Experiment:
#  0.9419990909287678
# Number of Heads in each Experiment:
#  0.9418867843027149
# Number of Heads in each Experiment:
#  0.9427059761643068
# Number of Heads in each Experiment:
#  0.9419238295950625
# Number of Heads in each Experiment:
#  0.9416922383639836
# Number of Heads in each Experiment:
#  0.9424915954690478
# Number of Heads in each Experiment:
#  0.942323881968334
# Number of Heads in each Experiment:
#  0.9423231914031683
# Number of Heads in each Experiment:
#  0.9416544328844068
# Number of Heads in each Experiment:
#  0.9414407337423834
# Number of Heads in each Experiment:
#  0.9424503718141565
# Number of Heads in each Experiment:
#  0.9420963615991206
# Number of Heads in each Experiment:
#  0.941511782451847
# Number of Heads in each Experiment:
#  0.9419149070545884
# Number of Heads in each Experiment:
#  0.9418478603390685
# Number of Heads in each Experiment:
#  0.9420662040628079
# Number of Heads in each Experiment:
#  0.9418213008096065
# Number of Heads in each Experiment:
#  0.9421744848750548
# Number of Heads in each Experiment:
#  0.9421282889939793
# Number of Heads in each Experiment:
#  0.9423525498430386
# Number of Heads in each Experiment:
#  0.941822783759673
# Number of Heads in each Experiment:
#  0.9427196124303845
# Number of Heads in each Experiment:
#  0.9423648271729923
# Number of Heads in each Experiment:
#  0.9418238799200016
# Number of Heads in each Experiment:
#  0.9418448180078599
# Number of Heads in each Experiment:
#  0.9420258310917641
# Number of Heads in each Experiment:
#  0.941792176389828
# Number of Heads in each Experiment:
#  0.9427312324901331
# Number of Heads in each Experiment:
#  0.9420440399175527
# Number of Heads in each Experiment:
#  0.9427302906254456
# Number of Heads in each Experiment:
#  0.9417125668177476
# Number of Heads in each Experiment:
#  0.9420843390600596
# Number of Heads in each Experiment:
#  0.9423513694054776
# Number of Heads in each Experiment:
#  0.9423264176481283
# Number of Heads in each Experiment:
#  0.9421543920485475
# Number of Heads in each Experiment:
#  0.942013239170238
# Number of Heads in each Experiment:
#  0.9418907250858416
# Number of Heads in each Experiment:
#  0.9424179876154787
# Number of Heads in each Experiment:
#  0.9420011599768005
# Number of Heads in each Experiment:
#  0.9418115406878106
# Number of Heads in each Experiment:
#  0.9430728471544392
# Number of Heads in each Experiment:
#  0.9422476690324249
# Number of Heads in each Experiment:
#  0.941602349159739
# Number of Heads in each Experiment:
#  0.9418783786459674
# Number of Heads in each Experiment:
#  0.942238295685856
# Number of Heads in each Experiment:
#  0.9418433561468216
# Number of Heads in each Experiment:
#  0.9425700281490522
# Number of Heads in each Experiment:
#  0.9425708728708669
# Number of Heads in each Experiment:
#  0.9419207466520264
# Number of Heads in each Experiment:
#  0.9414864679751864
# Number of Heads in each Experiment:
#  0.9426690884943654
# Number of Heads in each Experiment:
#  0.9427028712890587
# Number of Heads in each Experiment:
#  0.9416820684422482
# Number of Heads in each Experiment:
#  0.9425428632453738
# Number of Heads in each Experiment:
#  0.941454622972423
# Number of Heads in each Experiment:
#  0.9422467650529003
# Number of Heads in each Experiment:
#  0.9428466631918303
# Number of Heads in each Experiment:
#  0.9417410069170151
# Number of Heads in each Experiment:
#  0.942164573758197
# Number of Heads in each Experiment:
#  0.9423964991075028
# Number of Heads in each Experiment:
#  0.9417310013218138
# Number of Heads in each Experiment:
#  0.9427907688189519
# Number of Heads in each Experiment:
#  0.9426346825442262
# Number of Heads in each Experiment:
#  0.9420106283689834
# Number of Heads in each Experiment:
#  0.9419782893861334
# Number of Heads in each Experiment:
#  0.9421604903132768
# Number of Heads in each Experiment:
#  0.9417075434177383
# Number of Heads in each Experiment:
#  0.9424283094837527
# Number of Heads in each Experiment:
#  0.9420897718910964
# Number of Heads in each Experiment:
#  0.9425283892958701
# Number of Heads in each Experiment:
#  0.9425931843386403
# Number of Heads in each Experiment:
#  0.9428734920545581
# Number of Heads in each Experiment:
#  0.9416321791726747
# Number of Heads in each Experiment:
#  0.9417898730864843
# Number of Heads in each Experiment:
#  0.9424133878099289
# Number of Heads in each Experiment:
#  0.9421593638852163
# Number of Heads in each Experiment:
#  0.9421720785858999
# Number of Heads in each Experiment:
#  0.9419621157306914
# Number of Heads in each Experiment:
#  0.9424529175385641
# Number of Heads in each Experiment:
#  0.9420472819356389
# Number of Heads in each Experiment:
#  0.9420010700909577
# Number of Heads in each Experiment:
#  0.9419421373455369
# Number of Heads in each Experiment:
#  0.9425543648094704
# Number of Heads in each Experiment:
#  0.9419900552283444
# Number of Heads in each Experiment:
#  0.9423325580117581
# Number of Heads in each Experiment:
#  0.9415038116305003
# Number of Heads in each Experiment:
#  0.9423842630608931
# Number of Heads in each Experiment:
#  0.9427514981512176
# Number of Heads in each Experiment:
#  0.9421574153197214
# Number of Heads in each Experiment:
#  0.942828623799931
# Number of Heads in each Experiment:
#  0.9423742323508633
# Number of Heads in each Experiment:
#  0.9419630748087738
# Number of Heads in each Experiment:
#  0.9420425624086208
# Number of Heads in each Experiment:
#  0.9427217527612115
# Number of Heads in each Experiment:
#  0.9424183018291038
# Number of Heads in each Experiment:
#  0.9420531049711854
# Number of Heads in each Experiment:
#  0.9423917134101539
# Number of Heads in each Experiment:
#  0.9420529149746873
# Number of Heads in each Experiment:
#  0.9424278137890395
# Number of Heads in each Experiment:
#  0.9420545088322846
# Number of Heads in each Experiment:
#  0.9424102773971993
# Number of Heads in each Experiment:
#  0.9418145326015523
# Number of Heads in each Experiment:
#  0.9416286945266928
# Number of Heads in each Experiment:
#  0.9423904001699085
# Number of Heads in each Experiment:
#  0.9419179873147118
# Number of Heads in each Experiment:
#  0.9418299500890637
# Number of Heads in each Experiment:
#  0.9419464446048486
# Number of Heads in each Experiment:
#  0.9423489921091017
# Number of Heads in each Experiment:
#  0.9420518938264241
# Number of Heads in each Experiment:
#  0.9417698464124972
# Number of Heads in each Experiment:
#  0.9420639499309452
# Number of Heads in each Experiment:
#  0.9427496902322822
# Number of Heads in each Experiment:
#  0.9422797512238463
# Number of Heads in each Experiment:
#  0.941945357472044
# Number of Heads in each Experiment:
#  0.9425721775663617
# Number of Heads in each Experiment:
#  0.9422263045701115
# Number of Heads in each Experiment:
#  0.9416688292590094
# Number of Heads in each Experiment:
#  0.9415018738881885
# Number of Heads in each Experiment:
#  0.9421078946914708
# Number of Heads in each Experiment:
#  0.9419355949123078
# Number of Heads in each Experiment:
#  0.942193433102524
# Number of Heads in each Experiment:
#  0.9422119689199157
# Number of Heads in each Experiment:
#  0.9421191417955171
# Number of Heads in each Experiment:
#  0.9419975726910651
# Number of Heads in each Experiment:
#  0.942402006791693
# Number of Heads in each Experiment:
#  0.9418953680516516
# Number of Heads in each Experiment:
#  0.9424431557286441
# Number of Heads in each Experiment:
#  0.9423609106806337
# Number of Heads in each Experiment:
#  0.9424247046660226
# Number of Heads in each Experiment:
#  0.9420838902895045
# Number of Heads in each Experiment:
#  0.9424671880542559
# Number of Heads in each Experiment:
#  0.9418205426552672
# Number of Heads in each Experiment:
#  0.9420868335549907
# Number of Heads in each Experiment:
#  0.9421656778877666
# Number of Heads in each Experiment:
#  0.9422425798224862
# Number of Heads in each Experiment:
#  0.9420428468534865
# Number of Heads in each Experiment:
#  0.9418822427718601
# Number of Heads in each Experiment:
#  0.9424199929884309
# Number of Heads in each Experiment:
#  0.9424609589840169
# Number of Heads in each Experiment:
#  0.9423886457796044
# Number of Heads in each Experiment:
#  0.9424544442783342
# Number of Heads in each Experiment:
#  0.9418732691000149
# Number of Heads in each Experiment:
#  0.9422625453220973
# Number of Heads in each Experiment:
#  0.9422026082213517
# Number of Heads in each Experiment:
#  0.9424613455223512
# Number of Heads in each Experiment:
#  0.9422035880792738
# Number of Heads in each Experiment:
#  0.9422854887255144
# Number of Heads in each Experiment:
#  0.9420108044202886
# Number of Heads in each Experiment:
#  0.9420976705299913
# Number of Heads in each Experiment:
#  0.9420025858823915
# Number of Heads in each Experiment:
#  0.9422721850950148
# Number of Heads in each Experiment:
#  0.9420466224042022
# Number of Heads in each Experiment:
#  0.9422892135307243
# Number of Heads in each Experiment:
#  0.9415131461277052
# Number of Heads in each Experiment:
#  0.9421908735247805
# Number of Heads in each Experiment:
#  0.9422408064699114
# Number of Heads in each Experiment:
#  0.941863400268604
# Number of Heads in each Experiment:
#  0.9417456906996656
# Number of Heads in each Experiment:
#  0.9417202948339543
# Number of Heads in each Experiment:
#  0.942229593726349
# Number of Heads in each Experiment:
#  0.9419912863137249
# Number of Heads in each Experiment:
#  0.9426927336639861
# Number of Heads in each Experiment:
#  0.9423807310780276
# Number of Heads in each Experiment:
#  0.9422585238636182
# Number of Heads in each Experiment:
#  0.9424833469113912
# Number of Heads in each Experiment:
#  0.942594216998134
# Number of Heads in each Experiment:
#  0.9425343545484944
# Number of Heads in each Experiment:
#  0.9424190394429341
# Number of Heads in each Experiment:
#  0.9422612339486675
# Number of Heads in each Experiment:
#  0.9424874407695599
# Number of Heads in each Experiment:
#  0.9422967991012801
# Number of Heads in each Experiment:
#  0.9419551033948911
# Number of Heads in each Experiment:
#  0.9419551742086087
# Number of Heads in each Experiment:
#  0.94268751673202
# Number of Heads in each Experiment:
#  0.9418405370984733
# Number of Heads in each Experiment:
#  0.9421971397623271
# Number of Heads in each Experiment:
#  0.9416294415448033
# Number of Heads in each Experiment:
#  0.9419195317757155
# Number of Heads in each Experiment:
#  0.9419555944438368
# Number of Heads in each Experiment:
#  0.9421756290853497
# Number of Heads in each Experiment:
#  0.9423871902306817
# Number of Heads in each Experiment:
#  0.9420071227508126
# Number of Heads in each Experiment:
#  0.9420102172326517
# Number of Heads in each Experiment:
#  0.9423156230135967
# Number of Heads in each Experiment:
#  0.941903376108729
# Number of Heads in each Experiment:
#  0.9422760080987929
# Number of Heads in each Experiment:
#  0.9424005802379593
# Number of Heads in each Experiment:
#  0.9425263093018598
# Number of Heads in each Experiment:
#  0.9415901293826249
# Number of Heads in each Experiment:
#  0.9418457473771524
# Number of Heads in each Experiment:
#  0.9423183693501633
# Number of Heads in each Experiment:
#  0.9424970521125251
# Number of Heads in each Experiment:
#  0.9419565450069571
# Number of Heads in each Experiment:
#  0.9421795087097907
# Number of Heads in each Experiment:
#  0.9423362448743159
# Number of Heads in each Experiment:
#  0.9423463874218049
# Number of Heads in each Experiment:
#  0.9420875062689017
# Number of Heads in each Experiment:
#  0.9423984461540796
# Number of Heads in each Experiment:
#  0.9423948121998151
# Number of Heads in each Experiment:
#  0.9421627509417406
# Number of Heads in each Experiment:
#  0.9420325976948989
# Number of Heads in each Experiment:
#  0.9421999668179967
# Number of Heads in each Experiment:
#  0.9421258715983193
# Number of Heads in each Experiment:
#  0.9419873385362626
# Number of Heads in each Experiment:
#  0.9419753457155298
# Number of Heads in each Experiment:
#  0.9420473456170072
# Number of Heads in each Experiment:
#  0.9423346955883894
# Number of Heads in each Experiment:
#  0.9421503415494537
# Number of Heads in each Experiment:
#  0.9420172833241295
# Number of Heads in each Experiment:
#  0.941877170235913
# Number of Heads in each Experiment:
#  0.9424815106918052
# Number of Heads in each Experiment:
#  0.9423931293740063
# Number of Heads in each Experiment:
#  0.9416121422530823
# Number of Heads in each Experiment:
#  0.9421460422808551
# Number of Heads in each Experiment:
#  0.9418928714072277
# Number of Heads in each Experiment:
#  0.9422416212463627
# Number of Heads in each Experiment:
#  0.9418046931461188
# Number of Heads in each Experiment:
#  0.9421805275327315
# Number of Heads in each Experiment:
#  0.9422537903854356
# Number of Heads in each Experiment:
#  0.9423488641870164
# Number of Heads in each Experiment:
#  0.942012580460697
# Number of Heads in each Experiment:
#  0.9421399393859533
# Number of Heads in each Experiment:
#  0.9425373898042426
# Number of Heads in each Experiment:
#  0.9418942789156363
# Number of Heads in each Experiment:
#  0.9419410795760995
# Number of Heads in each Experiment:
#  0.9423312615536892
# Number of Heads in each Experiment:
#  0.9420226450196945
# Number of Heads in each Experiment:
#  0.94206760424377
# Number of Heads in each Experiment:
#  0.942071854031101
# Number of Heads in each Experiment:
#  0.9422656690930666
# Number of Heads in each Experiment:
#  0.9419184693862805
# Number of Heads in each Experiment:
#  0.9416978109983983
# Number of Heads in each Experiment:
#  0.9418481001714673
# Number of Heads in each Experiment:
#  0.9422152199248932
# Number of Heads in each Experiment:
#  0.942456286547607
# Number of Heads in each Experiment:
#  0.9423379865425173
# Number of Heads in each Experiment:
#  0.942331771751121
# Number of Heads in each Experiment:
#  0.9424157022074077
# Number of Heads in each Experiment:
#  0.9424708218454022
# Number of Heads in each Experiment:
#  0.9415700203991384
# Number of Heads in each Experiment:
#  0.941876896340508
# Number of Heads in each Experiment:
#  0.9425442027851666
# Number of Heads in each Experiment:
#  0.9417778156560276
# Number of Heads in each Experiment:
#  0.9424674827307414
# Number of Heads in each Experiment:
#  0.9414342573051373
# Number of Heads in each Experiment:
#  0.9421210449640033
# Number of Heads in each Experiment:
#  0.9421957316987049
# Number of Heads in each Experiment:
#  0.9420501826490458
# Number of Heads in each Experiment:
#  0.9417585667807495
# Number of Heads in each Experiment:
#  0.9418981448924769
# Number of Heads in each Experiment:
#  0.9424390106880521
# Number of Heads in each Experiment:
#  0.9416852498562432
# Number of Heads in each Experiment:
#  0.9424783966611112
# Number of Heads in each Experiment:
#  0.9424036027468148
# Number of Heads in each Experiment:
#  0.9420622617002555
# Number of Heads in each Experiment:
#  0.9418948131825219
# Number of Heads in each Experiment:
#  0.9422278241250122
# Number of Heads in each Experiment:
#  0.9423401621674247
# Number of Heads in each Experiment:
#  0.9419285843252178
# Number of Heads in each Experiment:
#  0.9424682043244893
# Number of Heads in each Experiment:
#  0.9419370922840404
# Number of Heads in each Experiment:
#  0.9420837886059668
# Number of Heads in each Experiment:
#  0.9420961036449773
# Number of Heads in each Experiment:
#  0.9423649328974772
# Number of Heads in each Experiment:
#  0.9420131954105315
# Number of Heads in each Experiment:
#  0.942325415056189
# Number of Heads in each Experiment:
#  0.9420557409925688
# Number of Heads in each Experiment:
#  0.9426962593105719
# Number of Heads in each Experiment:
#  0.942044629525623
# Number of Heads in each Experiment:
#  0.9420473044144403
# Number of Heads in each Experiment:
#  0.9423669075559077
# Number of Heads in each Experiment:
#  0.9421467647098948
# Number of Heads in each Experiment:
#  0.9421724499666218
# Number of Heads in each Experiment:
#  0.9422524863607298
# Number of Heads in each Experiment:
#  0.9415497072050651
# Number of Heads in each Experiment:
#  0.9423888413997097
# Number of Heads in each Experiment:
#  0.9421389954065663
# Number of Heads in each Experiment:
#  0.9422768298128578
# Number of Heads in each Experiment:
#  0.9421345657491115
# Number of Heads in each Experiment:
#  0.9422733836250523
# Number of Heads in each Experiment:
#  0.9415493052654277
# Number of Heads in each Experiment:
#  0.9422686101129191
# Number of Heads in each Experiment:
#  0.9420182524428435
# Number of Heads in each Experiment:
#  0.9422222520503081
# Number of Heads in each Experiment:
#  0.941798367314111
# Number of Heads in each Experiment:
#  0.9425415991753792
# Number of Heads in each Experiment:
#  0.9423550487292951
# Number of Heads in each Experiment:
#  0.9416643302492623
# Number of Heads in each Experiment:
#  0.942459433874215
# Number of Heads in each Experiment:
#  0.9422071610231555
# Number of Heads in each Experiment:
#  0.9416191274052207
# Number of Heads in each Experiment:
#  0.9417285295016002
# Number of Heads in each Experiment:
#  0.9419158897096855
# Number of Heads in each Experiment:
#  0.9422789102131097
# Number of Heads in each Experiment:
#  0.9422494411449585
# Number of Heads in each Experiment:
#  0.942453864546043
# Number of Heads in each Experiment:
#  0.9425245049537605
# Number of Heads in each Experiment:
#  0.9425211789040988
# Number of Heads in each Experiment:
#  0.9429928553571664
# Number of Heads in each Experiment:
#  0.9427418824982589
# Number of Heads in each Experiment:
#  0.9422592879358539
# Number of Heads in each Experiment:
#  0.9418946016434909
# Number of Heads in each Experiment:
#  0.9424156751874976
# Number of Heads in each Experiment:
#  0.9418713480869532
# Number of Heads in each Experiment:
#  0.9416326157621964
# Number of Heads in each Experiment:
#  0.9419303529289057
# Number of Heads in each Experiment:
#  0.9420437233890183
# Number of Heads in each Experiment:
#  0.9424441814800848
# Number of Heads in each Experiment:
#  0.9422799703899949
# Number of Heads in each Experiment:
#  0.9417569162527075
# Number of Heads in each Experiment:
#  0.9419657776453673
# Number of Heads in each Experiment:
#  0.9422439554468894
# Number of Heads in each Experiment:
#  0.9421906693711968
# Number of Heads in each Experiment:
#  0.9430742829124785
# Number of Heads in each Experiment:
#  0.941687607118465
# Number of Heads in each Experiment:
#  0.9425065314474718
# Number of Heads in each Experiment:
#  0.9425251603449827
# Number of Heads in each Experiment:
#  0.9424089549556488
# Number of Heads in each Experiment:
#  0.9422122793297522
# Number of Heads in each Experiment:
#  0.9421595114019027
# Number of Heads in each Experiment:
#  0.942110714696743
# Number of Heads in each Experiment:
#  0.9418372690003959
# Number of Heads in each Experiment:
#  0.9423617045700947
# Number of Heads in each Experiment:
#  0.9423459573763392
# Number of Heads in each Experiment:
#  0.9419040470223026
# Number of Heads in each Experiment:
#  0.9420642685607553
# Number of Heads in each Experiment:
#  0.9419119046712605
# Number of Heads in each Experiment:
#  0.9422174623895768
# Number of Heads in each Experiment:
#  0.9424513613751725
# Number of Heads in each Experiment:
#  0.9419805059354496
# Number of Heads in each Experiment:
#  0.9421863360311107
# Number of Heads in each Experiment:
#  0.9421356603321521
# Number of Heads in each Experiment:
#  0.9419705041498218
# Number of Heads in each Experiment:
#  0.9423101596206337
# Number of Heads in each Experiment:
#  0.9421075112121707
# Number of Heads in each Experiment:
#  0.9420458965383119
# Number of Heads in each Experiment:
#  0.9419831831681307
# Number of Heads in each Experiment:
#  0.9425251248419919
# Number of Heads in each Experiment:
#  0.941951975600305
# Number of Heads in each Experiment:
#  0.9420906106041123
# Number of Heads in each Experiment:
#  0.9419333923517164
# Number of Heads in each Experiment:
#  0.9425075652856129
# Number of Heads in each Experiment:
#  0.9421163915871693
# Number of Heads in each Experiment:
#  0.9426938795791356
# Number of Heads in each Experiment:
#  0.9418568007841094
# Number of Heads in each Experiment:
#  0.9421791551529721
# Number of Heads in each Experiment:
#  0.94217398299526
# Number of Heads in each Experiment:
#  0.9422973758049963
# Number of Heads in each Experiment:
#  0.9421698497549413
# Number of Heads in each Experiment:
#  0.9426406579450315
# Number of Heads in each Experiment:
#  0.9423812514624205
# Number of Heads in each Experiment:
#  0.9422897627335457
# Number of Heads in each Experiment:
#  0.9426530386604587
# Number of Heads in each Experiment:
#  0.9425553060698642
# Number of Heads in each Experiment:
#  0.9420987487898432
# Number of Heads in each Experiment:
#  0.9420753723944627
# Number of Heads in each Experiment:
#  0.9424811432623073
# Number of Heads in each Experiment:
#  0.9426588197946301
# Number of Heads in each Experiment:
#  0.9420946086023341
# Number of Heads in each Experiment:
#  0.9423722000950049
# Number of Heads in each Experiment:
#  0.9425700417269863
# Number of Heads in each Experiment:
#  0.9422157689456994
# Number of Heads in each Experiment:
#  0.9422822538561425
# Number of Heads in each Experiment:
#  0.9423582744451583
# Number of Heads in each Experiment:
#  0.9421157128848319
# Number of Heads in each Experiment:
#  0.9421651491517636
# Number of Heads in each Experiment:
#  0.942323160348305
# Number of Heads in each Experiment:
#  0.9422383324688484
# Number of Heads in each Experiment:
#  0.9422308164961868
# Number of Heads in each Experiment:
#  0.9420416120142958
# Number of Heads in each Experiment:
#  0.9422098292087836
# Number of Heads in each Experiment:
#  0.9422587964130082
# Number of Heads in each Experiment:
#  0.9425378592582823
# Number of Heads in each Experiment:
#  0.9424941018670435
# Number of Heads in each Experiment:
#  0.9419528474539778
# Number of Heads in each Experiment:
#  0.9418525465645572
# Number of Heads in each Experiment:
#  0.9424267013520125
# Number of Heads in each Experiment:
#  0.942261713209616
# Number of Heads in each Experiment:
#  0.9421340222140213
# Number of Heads in each Experiment:
#  0.9420244705770443
# Number of Heads in each Experiment:
#  0.9423819194546383
# Number of Heads in each Experiment:
#  0.9419769634998398
# Number of Heads in each Experiment:
#  0.9425516285352069
# Number of Heads in each Experiment:
#  0.942537958130673
# Number of Heads in each Experiment:
#  0.9422902802567346
# Number of Heads in each Experiment:
#  0.9416346914440207
# Number of Heads in each Experiment:
#  0.9419346469970873
# Number of Heads in each Experiment:
#  0.9419629921909047
# Number of Heads in each Experiment:
#  0.9424218538605428
# Number of Heads in each Experiment:
#  0.942314426387469
# Number of Heads in each Experiment:
#  0.9419279116442295
# Number of Heads in each Experiment:
#  0.942698209868583
# Number of Heads in each Experiment:
#  0.9422442360159717
# Number of Heads in each Experiment:
#  0.9422591548636858
# Number of Heads in each Experiment:
#  0.9424153923435474
# Number of Heads in each Experiment:
#  0.9420870234886407
# Number of Heads in each Experiment:
#  0.94260206757497
# Number of Heads in each Experiment:
#  0.9420286143351067
# Number of Heads in each Experiment:
#  0.9421541609981279
# Number of Heads in each Experiment:
#  0.9423432945029675
# Number of Heads in each Experiment:
#  0.9424855860140834
# Number of Heads in each Experiment:
#  0.9421153868437214
# Number of Heads in each Experiment:
#  0.9420724297172487
# Number of Heads in each Experiment:
#  0.9420850626004323
# Number of Heads in each Experiment:
#  0.9423332294084364
# Number of Heads in each Experiment:
#  0.9422221196987347
# Number of Heads in each Experiment:
#  0.9418704853630718
# Number of Heads in each Experiment:
#  0.942304461398603
# Number of Heads in each Experiment:
#  0.9421339984597878
# Number of Heads in each Experiment:
#  0.9419088184980655
# Number of Heads in each Experiment:
#  0.9424043302255708
# Number of Heads in each Experiment:
#  0.9423362848077341
# Number of Heads in each Experiment:
#  0.9418942575027746
# Number of Heads in each Experiment:
#  0.9420566622095747
# Number of Heads in each Experiment:
#  0.9420029451718588
# Number of Heads in each Experiment:
#  0.942146611783218
# Number of Heads in each Experiment:
#  0.9426874409175294
# Number of Heads in each Experiment:
#  0.9421804075038964
# Number of Heads in each Experiment:
#  0.9422552016454359
# Number of Heads in each Experiment:
#  0.9420596815019125
# Number of Heads in each Experiment:
#  0.942405414904593
# Number of Heads in each Experiment:
#  0.9421965776152026
# Number of Heads in each Experiment:
#  0.9421024649042432
# Number of Heads in each Experiment:
#  0.9420300335589429
# Number of Heads in each Experiment:
#  0.942327964695658
# Number of Heads in each Experiment:
#  0.9415463185307945
# Number of Heads in each Experiment:
#  0.9418801590072184
# Number of Heads in each Experiment:
#  0.9418994162045421
# Number of Heads in each Experiment:
#  0.9421096392175369
# Number of Heads in each Experiment:
#  0.9420298313150245
# Number of Heads in each Experiment:
#  0.9421295725384244
# Number of Heads in each Experiment:
#  0.941928981758323
# Number of Heads in each Experiment:
#  0.9419838704265053
# Number of Heads in each Experiment:
#  0.9422542764885309
# Number of Heads in each Experiment:
#  0.9420006473142041
# Number of Heads in each Experiment:
#  0.9420474688130567
# Number of Heads in each Experiment:
#  0.9421120032070912
# Number of Heads in each Experiment:
#  0.9423254468804574
# Number of Heads in each Experiment:
#  0.9418417573138076
# Number of Heads in each Experiment:
#  0.9424268321106314
# Number of Heads in each Experiment:
#  0.942342102637443
# Number of Heads in each Experiment:
#  0.9423062867520847
# Number of Heads in each Experiment:
#  0.9421732060486057
# Number of Heads in each Experiment:
#  0.9425619606413189
# Number of Heads in each Experiment:
#  0.9420149887970332
# Number of Heads in each Experiment:
#  0.9420535606002138
# Number of Heads in each Experiment:
#  0.9421360998226892
# Number of Heads in each Experiment:
#  0.9421271493162892
# Number of Heads in each Experiment:
#  0.9425797518708585
# Number of Heads in each Experiment:
#  0.9424012908749629
# Number of Heads in each Experiment:
#  0.9421760726307825
# Number of Heads in each Experiment:
#  0.9423204565119768
# Number of Heads in each Experiment:
#  0.94223914399186
# Number of Heads in each Experiment:
#  0.9419897050305461
# Number of Heads in each Experiment:
#  0.9418718136264888
# Number of Heads in each Experiment:
#  0.9422067371130086
# Number of Heads in each Experiment:
#  0.9420180608054378
# Number of Heads in each Experiment:
#  0.9426045418439407
# Number of Heads in each Experiment:
#  0.9418886751230965
# Number of Heads in each Experiment:
#  0.9421754378345512
# Number of Heads in each Experiment:
#  0.9422945521198252
# Number of Heads in each Experiment:
#  0.9421696406322791
# Number of Heads in each Experiment:
#  0.9419227064642157
# Number of Heads in each Experiment:
#  0.9423292721159772
# Number of Heads in each Experiment:
#  0.9418408008552823
# Number of Heads in each Experiment:
#  0.9418301852191454
# Number of Heads in each Experiment:
#  0.9417840324996498
# Number of Heads in each Experiment:
#  0.9419500328306477
# Number of Heads in each Experiment:
#  0.9421414823496521
# Number of Heads in each Experiment:
#  0.9422272585686513
# Number of Heads in each Experiment:
#  0.942156200040772
# Number of Heads in each Experiment:
#  0.941820559265174
# Number of Heads in each Experiment:
#  0.9422918384171476
# Number of Heads in each Experiment:
#  0.9422551630463846
# Number of Heads in each Experiment:
#  0.9418211343895898
# Number of Heads in each Experiment:
#  0.9422236689042807
# Number of Heads in each Experiment:
#  0.9423534930331233
# Number of Heads in each Experiment:
#  0.9424191435660962
# Number of Heads in each Experiment:
#  0.9418452995180903
# Number of Heads in each Experiment:
#  0.9427529994367754
# Number of Heads in each Experiment:
#  0.9425600577488562
# Number of Heads in each Experiment:
#  0.94176731954062
# Number of Heads in each Experiment:
#  0.9424349318333493
# Number of Heads in each Experiment:
#  0.9421212473942074
# Number of Heads in each Experiment:
#  0.9424519825371824
# Number of Heads in each Experiment:
#  0.9418559466109122
# Number of Heads in each Experiment:
#  0.942331831942701
# Number of Heads in each Experiment:
#  0.9424663596800876
# Number of Heads in each Experiment:
#  0.9419448216334565
# Number of Heads in each Experiment:
#  0.9420353098284981
# Number of Heads in each Experiment:
#  0.9419239293704899
# Number of Heads in each Experiment:
#  0.9423940986978101
# Number of Heads in each Experiment:
#  0.942392637393738
# Number of Heads in each Experiment:
#  0.9419409220845855
# Number of Heads in each Experiment:
#  0.9418384744929447
# Number of Heads in each Experiment:
#  0.942292139058108
# Number of Heads in each Experiment:
#  0.9418586444817904
# Number of Heads in each Experiment:
#  0.9422665039989155
# Number of Heads in each Experiment:
#  0.9424026833053822
# Number of Heads in each Experiment:
#  0.941904870917056
# Number of Heads in each Experiment:
#  0.9421253417324145
# Number of Heads in each Experiment:
#  0.9417981121691363
# Number of Heads in each Experiment:
#  0.9421354550264002
# Number of Heads in each Experiment:
#  0.9418223645350825
# Number of Heads in each Experiment:
#  0.9419353836916802
# Number of Heads in each Experiment:
#  0.9426903548050175
# Number of Heads in each Experiment:
#  0.9424479085959856
# Number of Heads in each Experiment:
#  0.9425929556970516
# Number of Heads in each Experiment:
#  0.942287192915537
# Number of Heads in each Experiment:
#  0.9421138814224365
# Number of Heads in each Experiment:
#  0.9421713768376868
# Number of Heads in each Experiment:
#  0.9423017235177439
# Number of Heads in each Experiment:
#  0.9418229792301928
# Number of Heads in each Experiment:
#  0.9424590517020338
# Number of Heads in each Experiment:
#  0.9419760043442178
# Number of Heads in each Experiment:
#  0.9421049938076376
# Number of Heads in each Experiment:
#  0.9424494637069151
# Number of Heads in each Experiment:
#  0.9425562558094401
# Number of Heads in each Experiment:
#  0.9421403863225886
# Number of Heads in each Experiment:
#  0.9424011987645385
# Number of Heads in each Experiment:
#  0.9419282899359477
# Number of Heads in each Experiment:
#  0.9421521652882473
# Number of Heads in each Experiment:
#  0.9420219306714362
# Number of Heads in each Experiment:
#  0.942303123826154
# Number of Heads in each Experiment:
#  0.9423160008519184
# Number of Heads in each Experiment:
#  0.9419549953901176
# Number of Heads in each Experiment:
#  0.9421240675701663
# Number of Heads in each Experiment:
#  0.9420774309663199
# Number of Heads in each Experiment:
#  0.9422985626407814
# Number of Heads in each Experiment:
#  0.9418936236768549
# Number of Heads in each Experiment:
#  0.9418574409532162
# Number of Heads in each Experiment:
#  0.9421425766105075
# Number of Heads in each Experiment:
#  0.9421856922968582
# Number of Heads in each Experiment:
#  0.9420297283444388
# Number of Heads in each Experiment:
#  0.9418821096173733
# Number of Heads in each Experiment:
#  0.9422613614707976
# Number of Heads in each Experiment:
#  0.9417240308213345
# Number of Heads in each Experiment:
#  0.9417653476942173

# %%
plt.plot(Prob_expt)
plt.xlabel('Number of Heads in each Experiment')
plt.ylabel('Probability of Occurrence',)
plt.show()

# %% [markdown]
# we find that at a certain number the probabilities are almost identical to 0.942, so we can deduce that the probability of heads is 0.942.

# %% [markdown]
# # Let's check the actual probability of the face by displaying the result of the random selection.

# %%
Prob_ty
# Out:
# 0.9421731010807519

# %% [markdown]
# we can conclude that the greater the number of trials, the greater the chance of determining the probability of heads
